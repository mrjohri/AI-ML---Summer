# %%
*******statistics***
1.Descriptive statistics are for describing the properties of sample and population data (what has happened)
2.Inferential statistics use those properties to test hypotheses, reach conclusions, and make predictions (what can you expect).


Use of Statistics in Machine Learning::::

*Asking questions about the data
*Cleaning and preprocessing the data
*Selecting the right features
*Model evaluation
*Model prediction


1.Population and sample
:::::Population::::
In statistics, the population comprises all observations (data points) about the subject under study.
:::::sample::::
In statistics, a sample is a subset of the population. It is a small portion of the total observed population.


2.Measures of Central Tendency
	1.Mean
	2.Median
	3.Mode
3.Variance and Standard Deviation
:::::Standard Deviation::::
The Standard Deviation is a measure of how spread out our data is.
;;;;;Variance:::
Variance measures the spread between all data points in a dataset.

::;:Covariance::::
Covariance finds the direction of the relationship between two data points. It finds whether two data points are directly or inversely proportional.
# Out:
#   Cell In[1], line 2
#     1.Descriptive statistics are for describing the properties of sample and population data (what has happened)
#      ^
# SyntaxError: invalid decimal literal

# %%
1.univariate 
2.bivariate
3.multi variate

# %%
1.univariate --only one variable at time----histograms,bar charts,pie charts,boxplots  -----categorical or numerical
2.Bivariate--two varaibles---categorical or numerical

numerical vs numerical  -scatterplot
numerical vs categorical ---ANOVA 
categorical vs categorical ----Chi squared error test

3.multi variate analysis---many variables
clustering anlysis
principal component analysis PCA
Multi correspondence analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Line Graph

# %%
x=[1,2,3,5,6,89,8]
y=[3,5,6,8,9,4,9]

# %%
plt.plot(x,y)

# %%
x=np.linspace(1,15,10)
y=x**2

# %%
x
# Out:
# array([ 1.        ,  2.55555556,  4.11111111,  5.66666667,  7.22222222,
#         8.77777778, 10.33333333, 11.88888889, 13.44444444, 15.        ])

# %%
y
# Out:
# array([  1.        ,   6.5308642 ,  16.90123457,  32.11111111,
#         52.16049383,  77.04938272, 106.77777778, 141.34567901,
#        180.75308642, 225.        ])

# %%
plt.plot(x,y,'b->')

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
x=[1,2,6,8]
y=[3,8,1,10]
plt.plot(x,y,'b-*')

# %%
plt.plot(x,y,'b-*',ms=20)

# %%
plt.plot(x,y,'b-*',ms=20,mec='r')

# %%
plt.plot(x,y,'b-*',ms=20,mec='r')
plt.grid()

# %% [markdown]
# ### Subplots

# %%
x=np.linspace(1,15,10)
y=x**2

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'b--')
plt.subplot(2,2,2)
plt.plot(x,y,'r*')
plt.subplot(2,2,3)
plt.plot(x,y,'g*')
plt.subplot(2,2,4)
plt.plot(x,y,'r>')

# %%
fig=plt.figure()
ax1=fig.add_axes([0.1,0.1,0.8,0.8])
ax2=fig.add_axes([0.2,0.5,0.4,0.3])
#[left,bottom,width,height]
ax1.plot(x,y)

ax2.plot(y,x)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# ### Compare two plots

# %%
import matplotlib.pyplot as plt
import numpy as np
#day one, the age and speed of 7 cars:
x = np.array([5,7,8,7,2,17,2])
y = np.array([99,86,87,88,111,86,103])
plt.scatter(x, y, color = 'hotpink')
#day two, the age and speed of 13 cars:
x = np.array([2,2,8,1,15,8,12])
y = np.array([100,105,84,105,90,93,97])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ### Bar Chart

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y,color="red")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x,y,width=0.1)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ###
#        179.26205568, 166.42077314, 162.52647108, 159.78862909,
#        181.12232001, 182.09599874, 170.96923962, 166.74799954,
#        152.12946397, 157.82367956, 180.69891049, 173.00875673,
#        167.12598433, 169.73315061, 176.46489765, 175.33815073,
#        159.67911765, 160.37555547, 198.29958667, 184.63400035,
#        159.47981748, 161.27729315, 170.9681701 , 166.48263868,
#        177.42883862, 162.41723956, 160.91140663, 168.29964841,
#        162.33292793, 162.7504675 , 170.95052272, 184.37020038,
#        172.29169965, 181.53717167, 178.80244639, 177.73844989,
#        171.93476488, 172.83954957, 157.41285023, 171.25181424,
#        153.39678057, 164.18593754, 192.98906693, 177.81840949,
#        176.66338999, 162.73742035])

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
import matplotlib.pyplot as plt
labels=["php","pyhton","java","c"]
numbers=[75,70,80,60]
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])  #[left,bottom,width,height]
axes1.pie(numbers,labels=labels,autopct="%0.2f%%",colors=["orange","pink","green","blue"])
axes1.legend()

# %%
#=["php","pyhton","java","c"]
Explode=[0.5,0,0,0.2]
plt.pie(numbers,labels=labels,explode=Explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c101040690>,
#   <matplotlib.patches.Wedge at 0x1c101041310>,
#   <matplotlib.patches.Wedge at 0x1c1010423d0>,
#   <matplotlib.patches.Wedge at 0x1c101043910>],
#  [Text(1.0836504797969189, 1.1771582891165944, 'php'),
#   Text(-0.8295173176268907, 0.7224271726320158, 'pyhton'),
#   Text(-0.6514587095050077, -0.8863416665203493, 'java'),
#   Text(1.0258827330394034, -0.7984764355017653, 'c')])

# %% [markdown]
# # Seaborn

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shrey\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\shrey\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\shrey\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\shrey\anaconda3\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shrey\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrey\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\shrey\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
Inference:from the plot we can say that as bill amount increases tip is alos increasing
# Out:
#   Cell In[47], line 1
#     Inference:from the plot we can say that as bill amount increases tip is alos increasing
#               ^
# SyntaxError: invalid syntax

# %%
sns.scatterplot(x="size",y="tip",data=df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(x="size",y="total_bill",data=df,ci=None)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_3532\3422416996.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="size",y="total_bill",data=df,ci=None)
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.distplot(df["tip"])
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_3532\2034962720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["tip"])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day")

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.barplot(data=df,x="day",y="tip",ci=None)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_3532\514399442.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="day",y="tip",ci=None)
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=df,x="sex",y="tip",hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x="sex",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
age
1 2 7 9 2 34 37 200
1 2 2 7 9 34 37 200
Q1=2 =LOWER QUARTILE

Median ==9+7/2=8 Q2

Q3=35.5=UPEER QUARTILLE

IQR=INTER QUARTILE RANGE=Q3-Q1
# Out:
#   Cell In[57], line 2
#     1 2 7 9 2 34 37 200
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
Correlation

positive correlation
negative correlation
neutral correlation
# Out:
#   Cell In[59], line 3
#     positive correlation
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
corr=df.corr()
corr
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_3532\3182140910.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
>0.5 is highly correlated
<0.5 is less correlated
# Out:
#   Cell In[61], line 1
#     >0.5 is highly correlated
#     ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >
